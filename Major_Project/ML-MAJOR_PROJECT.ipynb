# %% [markdown]
# # Verzeo - Major Project
#
# ### Done by : YUDHEKSHA GK

# %% [markdown]
# #### First let us import the required Libraries

# %%
import re
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
from collections import Counter

from nltk.tokenize import word_tokenize,sent_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer,PorterStemmer

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# #### Let us read the given Dataset

# %%
information = pd.read_excel('information.xlsx')

# %% [markdown]
# ## Exploratory data analysis and Data Cleaning

# %%
information.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#                created  ...  \
# 0  2013-05-12 01:48:00  ...
# 1  2012-01-10 13:51:00  ...
# 2       11/28/14 11:30  ...
# 3  2009-11-06 22:39:00  ...
# 4        4/16/14 13:23  ...
#
#                                         profileimage  retweet_count  \
# 0  https://pbs.twimg.com/profile_images/414342229...              0
# 1  https://pbs.twimg.com/profile_images/539604221...              0
# 2  https://pbs.twimg.com/profile_images/657330418...              1
# 3  https://pbs.twimg.com/profile_images/259703936...              0
# 4  https://pbs.twimg.com/profile_images/564094871...              0
#
#   sidebar_color                                               text  \
# 0        FFFFFF  Robbie E Responds To Critics After Win Against...
# 1        C0DEED  ‰ÛÏIt felt like they were my friends and I was...
# 2        C0DEED  i absolutely adore when louis starts the songs...
# 3        C0DEED  Hi @JordanSpieth - Looking at the url - do you...
# 4             0  Watching Neighbours on Sky+ catching up with t...
#
#   tweet_coord tweet_count   tweet_created            tweet_id  \
# 0         NaN      110964  10/26/15 12:40  658730000000000000
# 1         NaN        7471  10/26/15 12:40  658730000000000000
# 2         NaN        5617  10/26/15 12:40  658730000000000000
# 3         NaN        1693  10/26/15 12:40  658730000000000000
# 4         NaN       31462  10/26/15 12:40  658730000000000000
#
#     tweet_location               user_timezone
# 0  main; @Kan1shk3                     Chennai
# 1              NaN  Eastern Time (US & Canada)
# 2           clcncl                    Belgrade
# 3    Palo Alto, CA  Pacific Time (US & Canada)
# 4              NaN                         NaN
#
# [5 rows x 26 columns]

# %%
information.shape
# Out:
# (20050, 26)

# %%
information.columns.tolist()
# Out:
# ['_unit_id',
#  '_golden',
#  '_unit_state',
#  '_trusted_judgments',
#  '_last_judgment_at',
#  'gender',
#  'gender:confidence',
#  'profile_yn',
#  'profile_yn:confidence',
#  'created',
#  'description',
#  'fav_number',
#  'gender_gold',
#  'link_color',
#  'name',
#  'profile_yn_gold',
#  'profileimage',
#  'retweet_count',
#  'sidebar_color',
#  'text',
#  'tweet_coord',
#  'tweet_count',
#  'tweet_created',
#  'tweet_id',
#  'tweet_location',
#  'user_timezone']

# %%
information.describe()
# Out:
#            _unit_id  _trusted_judgments  gender:confidence  \
# count  2.005000e+04        20050.000000       20024.000000
# mean   8.157294e+08            3.615711           0.882756
# std    6.000801e+03           12.331890           0.191403
# min    8.157192e+08            3.000000           0.000000
# 25%    8.157243e+08            3.000000           0.677800
# 50%    8.157294e+08            3.000000           1.000000
# 75%    8.157345e+08            3.000000           1.000000
# max    8.157580e+08          274.000000           1.000000
#
#        profile_yn:confidence     fav_number  retweet_count   tweet_count  \
# count           20050.000000   20050.000000   20050.000000  2.005000e+04
# mean                0.993221    4382.201646       0.079401  3.892469e+04
# std                 0.047168   12518.575919       2.649751  1.168371e+05
# min                 0.627200       0.000000       0.000000  1.000000e+00
# 25%                 1.000000      11.000000       0.000000  2.398000e+03
# 50%                 1.000000     456.000000       0.000000  1.144150e+04
# 75%                 1.000000    3315.500000       0.000000  4.002750e+04
# max                 1.000000  341621.000000     330.000000  2.680199e+06
#
#            tweet_id
# count  2.005000e+04
# mean   6.587350e+17
# std    5.000124e+12
# min    6.587300e+17
# 25%    6.587300e+17
# 50%    6.587300e+17
# 75%    6.587400e+17
# max    6.587400e+17

# %%
information.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16301 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
#  14  name                   20050 non-null  object
#  15  profile_yn_gold        50 non-null     object
#  16  profileimage           20050 non-null  object
#  17  retweet_count          20050 non-null  int64
#  18  sidebar_color          20050 non-null  object
#  19  text                   20048 non-null  object
#  20  tweet_coord            159 non-null    object
#  21  tweet_count            20050 non-null  int64
#  22  tweet_created          20050 non-null  object
#  23  tweet_id               20050 non-null  int64
#  24  tweet_location         12564 non-null  object
#  25  user_timezone          12252 non-null  object
# dtypes: bool(1), float64(2), int64(6), object(17)
# memory usage: 3.8+ MB

# %%
information.isnull().sum() # Checking the Missing Values in each Column of the DataFrame
# Out:
# _unit_id                     0
# _golden                      0
# _unit_state                  0
# _trusted_judgments           0
# _last_judgment_at           50
# gender                      97
# gender:confidence           26
# profile_yn                   0
# profile_yn:confidence        0
# created                      0
# description               3749
# fav_number                   0
# gender_gold              20000
# link_color                   0
# name                         0
# profile_yn_gold          20000
# profileimage                 0
# retweet_count                0
# sidebar_color                0
# text                         2
# tweet_coord              19891
# tweet_count                  0
# tweet_created                0
# tweet_id                     0
# tweet_location            7486
# user_timezone             7798
# dtype: int64

# %%
information.corr()
# Out:
#                        _unit_id   _golden  _trusted_judgments  \
# _unit_id               1.000000  0.208055            0.207651
# _golden                0.208055  1.000000            0.998592
# _trusted_judgments     0.207651  0.998592            1.000000
# gender:confidence      0.007918  0.008818            0.009550
# profile_yn:confidence  0.015168  0.005592            0.005543
# fav_number             0.024878  0.003794            0.003851
# retweet_count         -0.004337 -0.000744           -0.000765
# tweet_count           -0.024809 -0.009669           -0.009703
# tweet_id               0.844887 -0.005985           -0.005781
#
#                        gender:confidence  profile_yn:confidence  fav_number  \
# _unit_id                        0.007918               0.015168    0.024878
# _golden                         0.008818               0.005592    0.003794
# _trusted_judgments              0.009550               0.005543    0.003851
# gender:confidence               1.000000               0.313628   -0.030889
# profile_yn:confidence           0.313628               1.000000   -0.003256
# fav_number                     -0.030889              -0.003256    1.000000
# retweet_count                  -0.004947               0.001376    0.008274
# tweet_count                    -0.013558              -0.012665    0.066733
# tweet_id                        0.027901               0.019044    0.041788
#
#                        retweet_count  tweet_count  tweet_id
# _unit_id                   -0.004337    -0.024809  0.844887
# _golden                    -0.000744    -0.009669 -0.005985
# _trusted_judgments         -0.000765    -0.009703 -0.005781
# gender:confidence          -0.004947    -0.013558  0.027901
# profile_yn:confidence       0.001376    -0.012665  0.019044
# fav_number                  0.008274     0.066733  0.041788
# retweet_count               1.000000    -0.001263 -0.006466
# tweet_count                -0.001263     1.000000 -0.037836
# tweet_id                   -0.006466    -0.037836  1.000000

# %%
# HaetMap of the Correlation Matrix
sns.heatmap(information.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="retweet_count", data=information.loc[1:100,:], hue = 'gender')
# Out:
# <AxesSubplot:xlabel='retweet_count', ylabel='count'>

# %%
sns.countplot(x="tweet_count", data=information.loc[1:50,:], hue = 'gender')
# Out:
# <AxesSubplot:xlabel='tweet_count', ylabel='count'>

# %%
information.description
# Out:
# 0                                    i sing my own rhythm.
# 1        I'm the author of novels filled with family dr...
# 2                      louis whining and squealing and all
# 3        Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4        Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#                                ...
# 20045                                                 (rp)
# 20046    Whatever you like, it's not a problem at all. ...
# 20047    #TeamBarcelona ..You look lost so you should f...
# 20048    Anti-statist; I homeschool my kids. Aspiring t...
# 20049                       Teamwork makes the dream work.
# Name: description, Length: 20050, dtype: object

# %%
information.name
# Out:
# 0               sheezy0
# 1           DavdBurnett
# 2        lwtprettylaugh
# 3           douggarland
# 4          WilfordGemma
#               ...
# 20045       capuletrosa
# 20046        BenNight41
# 20047     realuzzyfluxz
# 20048      argumatronic
# 20049       MeganFitz20
# Name: name, Length: 20050, dtype: object

# %%
information.text
# Out:
# 0        Robbie E Responds To Critics After Win Against...
# 1        ‰ÛÏIt felt like they were my friends and I was...
# 2        i absolutely adore when louis starts the songs...
# 3        Hi @JordanSpieth - Looking at the url - do you...
# 4        Watching Neighbours on Sky+ catching up with t...
#                                ...
# 20045    @lookupondeath ...Fine, and I'll drink tea too...
# 20046    Greg Hardy you a good player and all but don't...
# 20047    You can miss people and still never want to se...
# 20048    @bitemyapp i had noticed your tendency to pee ...
# 20049    I think for my APUSH creative project I'm goin...
# Name: text, Length: 20050, dtype: object

# %%
information =  information[["gender", "name","description", "gender:confidence","text"]]

# %% [markdown]
# ###### Dropping the rows with NaN

# %%
information = information.dropna()

# %%
information.shape
# Out:
# (16217, 5)

# %% [markdown]
# #### Data Cleaning of "description" column

# %%
list_of_stopwords = list(stopwords.words('english'))

# %%
information.columns
# Out:
# Index(['gender', 'name', 'description', 'gender:confidence', 'text'], dtype='object')

# %%
# Taking only those rows which has type of description str. 
temp=[]
for i in range(information.shape[0]):
    temp.append(type(information['description'].values[i]) == str)

# %%
information = information.loc[temp,:]

# %%
stemmer = PorterStemmer()
words = stopwords.words("english")
# Data Cleaning using regex.
information['cleaned_description'] = information['description'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

# %%
information.head()
# Out:
#    gender            name                                        description  \
# 0    male         sheezy0                              i sing my own rhythm.
# 1    male     DavdBurnett  I'm the author of novels filled with family dr...
# 2    male  lwtprettylaugh                louis whining and squealing and all
# 3    male     douggarland  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4  female    WilfordGemma  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#
#    gender:confidence                                               text  \
# 0             1.0000  Robbie E Responds To Critics After Win Against...
# 1             1.0000  ‰ÛÏIt felt like they were my friends and I was...
# 2             0.6625  i absolutely adore when louis starts the songs...
# 3             1.0000  Hi @JordanSpieth - Looking at the url - do you...
# 4             1.0000  Watching Neighbours on Sky+ catching up with t...
#
#                                  cleaned_description
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 2                                  loui whine squeal
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...

# %% [markdown]
# #### Data Cleaning of "text" column

# %%
information.columns
# Out:
# Index(['gender', 'name', 'description', 'gender:confidence', 'text',
#        'cleaned_description'],
#       dtype='object')

# %%
stemmer = PorterStemmer()
words = stopwords.words("english")
information['cleaned_text'] = information['text'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

# %%
information.head()
# Out:
#    gender            name                                        description  \
# 0    male         sheezy0                              i sing my own rhythm.
# 1    male     DavdBurnett  I'm the author of novels filled with family dr...
# 2    male  lwtprettylaugh                louis whining and squealing and all
# 3    male     douggarland  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4  female    WilfordGemma  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#
#    gender:confidence                                               text  \
# 0             1.0000  Robbie E Responds To Critics After Win Against...
# 1             1.0000  ‰ÛÏIt felt like they were my friends and I was...
# 2             0.6625  i absolutely adore when louis starts the songs...
# 3             1.0000  Hi @JordanSpieth - Looking at the url - do you...
# 4             1.0000  Watching Neighbours on Sky+ catching up with t...
#
#                                  cleaned_description  \
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 2                                  loui whine squeal
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
#
#                                         cleaned_text
# 0  robbi e respond to critic after win against ed...
# 1  it felt like friend i live stori http co arng ...
# 2    absolut ador loui start song hit hard feel good
# 3  hi jordanspieth look url use ifttt don typic s...
# 4           watch neighbour ski catch neighb xxx xxx

# %% [markdown]
# ### Feature Selection and Feature Engineering

# %%
# Taking only those rows with full confidence in gender
information = information[information["gender:confidence"]==1]

# %%
information.head()
# Out:
#    gender           name                                        description  \
# 0    male        sheezy0                              i sing my own rhythm.
# 1    male    DavdBurnett  I'm the author of novels filled with family dr...
# 3    male    douggarland  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4  female   WilfordGemma  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
# 5  female  monroevicious                                 you don't know me.
#
#    gender:confidence                                               text  \
# 0                1.0  Robbie E Responds To Critics After Win Against...
# 1                1.0  ‰ÛÏIt felt like they were my friends and I was...
# 3                1.0  Hi @JordanSpieth - Looking at the url - do you...
# 4                1.0  Watching Neighbours on Sky+ catching up with t...
# 5                1.0  Ive seen people on the train with lamps, chair...
#
#                                  cleaned_description  \
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
# 5                                               know
#
#                                         cleaned_text
# 0  robbi e respond to critic after win against ed...
# 1  it felt like friend i live stori http co arng ...
# 3  hi jordanspieth look url use ifttt don typic s...
# 4           watch neighbour ski catch neighb xxx xxx
# 5  ive seen peopl train lamp chair tv etc http co...

# %%
X_information =  information[["name","cleaned_text","cleaned_description"]]  #Independent Variables

y_information = information[["gender"]]   # Dependent Variable

# %%
print (X_information.shape)
X_information.head()
# Out:
# (11825, 3)
#             name                                       cleaned_text  \
# 0        sheezy0  robbi e respond to critic after win against ed...
# 1    DavdBurnett  it felt like friend i live stori http co arng ...
# 3    douggarland  hi jordanspieth look url use ifttt don typic s...
# 4   WilfordGemma           watch neighbour ski catch neighb xxx xxx
# 5  monroevicious  ive seen peopl train lamp chair tv etc http co...
#
#                                  cleaned_description
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
# 5                                               know

# %%
print(X_information.shape)
y_information.head()
# Out:
# (11825, 3)
#    gender
# 0    male
# 1    male
# 3    male
# 4  female
# 5  female

# %% [markdown]
# ##### Label Encoding the gender column for ease of Calculation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_information['gender_encoded'] = le.fit_transform(y_information["gender"])
# Out:
# <ipython-input-33-aacfd1ffe886>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_information['gender_encoded'] = le.fit_transform(y_information["gender"])

# %%
y_information = y_information[["gender_encoded"]]

# %%
print(X_information.shape)
y_information.head()
# Out:
# (11825, 3)
#    gender_encoded
# 0               2
# 1               2
# 3               2
# 4               1
# 5               1

# %% [markdown]
# # Ensemble Machine Learning Modelling
#
# ## 1. Classification using Naive Bayes Algorithm

# %%
print (X_information.shape)
X_information.head()
# Out:
# (11825, 3)
#             name                                       cleaned_text  \
# 0        sheezy0  robbi e respond to critic after win against ed...
# 1    DavdBurnett  it felt like friend i live stori http co arng ...
# 3    douggarland  hi jordanspieth look url use ifttt don typic s...
# 4   WilfordGemma           watch neighbour ski catch neighb xxx xxx
# 5  monroevicious  ive seen peopl train lamp chair tv etc http co...
#
#                                  cleaned_description
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
# 5                                               know

# %%
print(y_information.shape)
y_information.head()
# Out:
# (11825, 1)
#    gender_encoded
# 0               2
# 1               2
# 3               2
# 4               1
# 5               1

# %%
# Splitting the data into Training and Testing Sets

Train_X_Nb, Test_X_Nb, Train_Y_Nb, Test_Y_Nb = train_test_split(X_information['cleaned_description'],y_information['gender_encoded'],test_size = 0.01, random_state=1)

# %%
# Doing Label Encoding for both Training and Testing Sets.

Encoder = LabelEncoder()
Train_Y_Nb = Encoder.fit_transform(Train_Y_Nb)
Test_Y_Nb = Encoder.fit_transform(Test_Y_Nb)

# %%
# Transforming text to feature vectors that can be used as input to estimator.

T_vect = TfidfVectorizer(max_features=5000)
T_vect.fit(X_information['cleaned_description'])
# Out:
# TfidfVectorizer(max_features=5000)

# %%
# Transforming the Train and Test sets.

Train_X_Nb_T = T_vect.transform(Train_X_Nb)
Test_X_Nb_T = T_vect.transform(Test_X_Nb)

# %%
# fit the training dataset on the NB classifier.

Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Nb_T,Train_Y_Nb)
# Out:
# MultinomialNB()

# %%
# predict the labels on validation dataset.

predictions_Nb = Naive.predict(Test_X_Nb_T)

# Use accuracy_score function to get the accuracy.

print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_Nb, Test_Y_Nb)*100)
# Out:
# Naive Bayes Accuracy Score ->  71.42857142857143

# %%
# Saving the Output by first converting it into Dataframe and then into CSV File.

df = pd.DataFrame(data=predictions_Nb, columns=["result"])
df.to_csv("result_via_NB.csv")

# %% [markdown]
# ## 2. Classification using Support Vector Machine Algorithm

# %%
print (X_information.shape)
X_information.head()
# Out:
# (11825, 3)
#             name                                       cleaned_text  \
# 0        sheezy0  robbi e respond to critic after win against ed...
# 1    DavdBurnett  it felt like friend i live stori http co arng ...
# 3    douggarland  hi jordanspieth look url use ifttt don typic s...
# 4   WilfordGemma           watch neighbour ski catch neighb xxx xxx
# 5  monroevicious  ive seen peopl train lamp chair tv etc http co...
#
#                                  cleaned_description
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
# 5                                               know

# %%
print (y_information.shape)
y_information.head()
# Out:
# (11825, 1)
#    gender_encoded
# 0               2
# 1               2
# 3               2
# 4               1
# 5               1

# %%
# Splitting the data into Training and Testing Sets

Train_X_Svm, Test_X_Svm, Train_Y_Svm, Test_Y_Svm = train_test_split(X_information['cleaned_description'],y_information['gender_encoded'],test_size = 0.01, random_state=10)

# %%
# Doing Label Encoding for both Training and Testing Sets.

Encoder = LabelEncoder()
Train_Y_Svm = Encoder.fit_transform(Train_Y_Svm)
Test_Y_Svm = Encoder.fit_transform(Test_Y_Svm)

# %%
# Transforming text to feature vectors that can be used as input to estimator.

T_vect = TfidfVectorizer(max_features=5000)
T_vect.fit(X_information['cleaned_description'])
# Out:
# TfidfVectorizer(max_features=5000)

# %%
# Transforming the Train and Test sets.

Train_X_Svm_T = T_vect.transform(Train_X_Svm)
Test_X_Svm_T = T_vect.transform(Test_X_Svm)

# %%
# fit the training dataset on the classifier

SVM = svm.SVC(C=2, kernel='linear', degree=2, gamma='auto')
SVM.fit(Train_X_Svm_T,Train_Y_Svm)
# Out:
# SVC(C=2, degree=2, gamma='auto', kernel='linear')

# %%
# predict the labels on validation dataset

predictions_Svm = SVM.predict(Test_X_Svm_T)

# Use accuracy_score function to get the accuracy

print("SVM Accuracy Score -> ",accuracy_score(predictions_Svm, Test_Y_Svm)*100)
# Out:
# SVM Accuracy Score ->  68.90756302521008

# %%
# Saving the Output by first converting it into Dataframe and then into CSV File.

df = pd.DataFrame(data=predictions_Svm, columns=["result"])
df.to_csv("result_via_SVM.csv")

# %% [markdown]
# ## 3. Classification using Logistic Regression Algorithm

# %%
print (X_information.shape)
X_information.head()
# Out:
# (11825, 3)
#             name                                       cleaned_text  \
# 0        sheezy0  robbi e respond to critic after win against ed...
# 1    DavdBurnett  it felt like friend i live stori http co arng ...
# 3    douggarland  hi jordanspieth look url use ifttt don typic s...
# 4   WilfordGemma           watch neighbour ski catch neighb xxx xxx
# 5  monroevicious  ive seen peopl train lamp chair tv etc http co...
#
#                                  cleaned_description
# 0                                        sing rhythm
# 1            i author novel fill famili drama romanc
# 3  mobil guy er shazam googl kleiner perkin yahoo...
# 4  ricki wilson the best frontman kaiser chief th...
# 5                                               know

# %%
print(y_information.shape)
y_information.head()
# Out:
# (11825, 1)
#    gender_encoded
# 0               2
# 1               2
# 3               2
# 4               1
# 5               1

# %%
# Splitting the data into Training and Testing Sets

Train_X_Lr, Test_X_Lr, Train_Y_Lr, Test_Y_Lr = train_test_split(X_information['cleaned_description'],y_information['gender_encoded'],test_size = 0.01, random_state=22)

# %%
# Doing Label Encoding for both Training and Testing Sets.

Encoder = LabelEncoder()
Train_Y_Lr = Encoder.fit_transform(Train_Y_Lr)
Test_Y_Lr = Encoder.fit_transform(Test_Y_Lr)

# %%
# Transforming text to feature vectors that can be used as input to estimator.

T_vect = TfidfVectorizer(max_features=5000)
T_vect.fit(X_information['cleaned_description'])
# Out:
# TfidfVectorizer(max_features=5000)

# %%
# Transforming the Train and Test sets.

Train_X_Lr_T = T_vect.transform(Train_X_Lr)
Test_X_Lr_T = T_vect.transform(Test_X_Lr)

# %%
# fit the training dataset on the classifier

lr = LogisticRegression(max_iter = 1000)
lr.fit(Train_X_Lr_T,Train_Y_Lr)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# predict the labels on validation dataset

predictions_Lr = lr.predict(Test_X_Lr_T)

# Use accuracy_score function to get the accuracy

print("LR Accuracy Score -> ",accuracy_score(predictions_Lr, Test_Y_Lr)*100)
# Out:
# LR Accuracy Score ->  70.58823529411765

# %%
# Saving the Output by first converting it into Dataframe and then into CSV File.

df = pd.DataFrame(data=predictions_Lr, columns=["result"])
df.to_csv("result_via_LR.csv")

# %% [markdown]
# ### Ensemble Machine Learning Modelling -> Choosing best Algo based on Accuracy

# %% [markdown]
# ###### From above Models, Accuracy obtained through
#
# 1. Naive Bayes Algorithm           is **71.42857142857143 %**
#
# 2. Support Vector Machine Algorithm is **68.0672268907563 %**
#
# 3. Logistic Regression Algorithm is  **70.58823529411765 %**

# %% [markdown]
# ###### So, For the given data set and the used hyperparameters, Based on the accuracy score , We can say **Naive Bias Algorithm is best** in this case.

# %% [markdown]
# # Questions on DataSet
#
# ## 1.What are the most common emotions/words used by Males and Females?
#
# #### 1.a For Males

# %%
# Reading the data and dropping null values

information = pd.read_excel('information.xlsx')
information =  information[["gender", "name","description", "gender:confidence","text"]]
information = information.dropna()

# %%
# Taking only those rows which has type of description str. 
temp=[]
for i in range(information.shape[0]):
    temp.append(type(information['description'].values[i]) == str)    
information = information.loc[temp,:]


# Data Cleaning
stemmer = PorterStemmer()
words = stopwords.words("english")
information['cleaned_description'] = information['description'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

stemmer = PorterStemmer()
words = stopwords.words("english")
information['cleaned_text'] = information['text'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())


# Feature Selection & Engineering
information = information[information["gender:confidence"]==1]
X_information =  information[["gender", "name","cleaned_text","cleaned_description"]]

# %%
X_information.gender.value_counts()
# Out:
# female     4606
# male       4141
# brand      3006
# unknown      72
# Name: gender, dtype: int64

# %%
# Taking only those rows with gender as "Male"

X_info_M = X_information.loc[ (X_information.gender == "male" )]

# %%
X_info_M.head()
# Out:
#    gender         name                                       cleaned_text  \
# 0    male      sheezy0  robbi e respond to critic after win against ed...
# 1    male  DavdBurnett  it felt like friend i live stori http co arng ...
# 3    male  douggarland  hi jordanspieth look url use ifttt don typic s...
# 7    male   RobinMeske  gala bingo club bought the uk largest high str...
# 17   male   SSmyth2010  coolyazzi ditto i still learn favourit retweet...
#
#                                   cleaned_description
# 0                                         sing rhythm
# 1             i author novel fill famili drama romanc
# 3   mobil guy er shazam googl kleiner perkin yahoo...
# 7                      the secret get ahead get start
# 17  over enthusiast f fan model collector music fa...

# %%
# Instantiating the Counter.
words_M = Counter()

# Taking the column named "cleaned_text" and counting the frequency of each word.
X_info_M['cleaned_text'].str.split().apply(words_M.update)

print(words_M)
# Out:
# Counter({'i': 1460, 'co': 1351, 'http': 1338, 'the': 524, 'get': 301, 'like': 278, 'go': 212, 'and': 207, 'one': 197, 'time': 185, 'make': 159, 'new': 158, 'love': 158, 'it': 146, 'day': 138, 'look': 136, 'you': 136, 'see': 135, 'peopl': 134, 'know': 132, 'good': 123, 'think': 123, 'want': 116, 'back': 114, 'got': 113, 'need': 113, 'best': 108, 'amp': 105, 'fuck': 104, 'game': 103, 'u': 103, 'say': 102, 'come': 102, 'year': 100, 'still': 99, 'thank': 97, 'a': 95, 'thing': 94, 'if': 94, 'work': 94, 'follow': 92, 'would': 92, 'great': 88, 'way': 85, 'play': 85, 'let': 82, 'last': 82, 'realli': 81, 'use': 80, 'lol': 80, 'via': 79, 'tri': 74, 'today': 73, 'take': 72, 'life': 72, 'shit': 71, 'well': 70, 'start': 69, 'even': 68, 'man': 68, 'first': 68, 'live': 67, 'world': 67, 'feel': 67, 'week': 66, 'watch': 65, 'next': 65, 'my': 64, 'hope': 63, 'that': 62, 'we': 62, 'alway': 62, 'right': 61, 'never': 61, 'much': 61, 'could': 61, 'in': 59, 'guy': 59, 'video': 58, 'just': 58, 'chang': 57, 'so': 57, 'what': 57, 'end': 57, 'he': 56, 'keep': 56, 'us': 55, 'made': 55, 'tell': 54, 'im': 53, 'show': 53, 'b': 53, 'win': 52, 'better': 52, 'of': 52, 'call': 52, 'when': 51, 'give': 51, 'ever': 51, 'also': 50, 'x': 50, 'night': 49, 'w': 49, 'big': 48, 'read': 48, 'lot': 48, 'nigga': 48, 'to': 47, 'someon': 47, 'music': 47, 'everi': 47, 'is': 47, 'talk': 47, 'friend': 46, 'no': 46, 'how': 46, 'gonna': 46, 'put': 46, 'ask': 46, 'stop': 45, 'v': 45, 'thi': 45, 'l': 44, 'real': 44, 'r': 44, 'eat': 44, 'c': 44, 'gt': 44, 'th': 44, 'team': 44, 'f': 44, 'build': 44, 'hous': 44, 'all': 43, 'mean': 43, 'two': 43, 'god': 43, 'song': 43, 'p': 42, 'word': 42, 'check': 42, 'someth': 42, 'but': 42, 'around': 42, 'person': 42, 'season': 41, 'rememb': 41, 'said': 41, 'k': 40, 'run': 40, 'happi': 40, 'n': 39, 'whi': 39, 'wonder': 39, 'home': 39, 'h': 38, 'mani': 38, 'there': 38, 'happen': 38, 'free': 38, 'car': 38, 'miss': 38, 'help': 38, 'girl': 37, 'find': 37, 'ye': 37, 'everyth': 37, 'pleas': 37, 'money': 37, 'thought': 37, 'e': 36, 'tweet': 36, 'noth': 36, 'wait': 36, 'boy': 36, 'alreadi': 36, 'point': 35, 'kid': 35, 'listen': 35, 'oh': 35, 'move': 35, 'on': 34, 'they': 34, 'hour': 34, 'half': 34, 'hate': 34, 'place': 34, 'not': 34, 'caus': 33, 'tonight': 33, 'yeah': 33, 'done': 33, 'everyon': 33, 'your': 33, 'halloween': 33, 'busi': 33, 'turn': 33, 'job': 32, 'd': 32, 'hit': 32, 'sure': 32, 'j': 32, 'long': 32, 'state': 32, 'nice': 32, 'old': 32, 'walk': 32, 'vote': 32, 'phone': 31, 'post': 31, 'book': 31, 'z': 31, 'unit': 31, 'lord': 31, 'app': 30, 'amaz': 30, 'enjoy': 30, 'g': 30, 'school': 30, 'yet': 30, 'head': 30, 'twitter': 30, 't': 29, 'without': 29, 'differ': 29, 'support': 29, 'player': 29, 'away': 29, 'dream': 29, 'bitch': 29, 'fan': 28, 'now': 28, 'parti': 28, 'drive': 28, 'youtub': 28, 'tomorrow': 28, 'quot': 28, 'probabl': 28, 'part': 28, 'stori': 27, 'face': 27, 'white': 27, 'excit': 27, 'fun': 27, 'bad': 27, 'me': 27, 'top': 27, 'believ': 27, 'problem': 27, 'hand': 27, 'hi': 26, 'past': 26, 'open': 26, 'sinc': 26, 'sit': 26, 'leav': 26, 'bring': 26, 'found': 26, 's': 26, 'brother': 26, 'becom': 26, 'buy': 26, 'don': 25, 'high': 25, 'littl': 25, 'pick': 25, 'set': 25, 'whole': 25, 'beauti': 25, 'name': 25, 'class': 25, 'space': 25, 'may': 25, 'final': 25, 'might': 25, 'actual': 25, 'stay': 25, 'learn': 24, 'star': 24, 'though': 24, 'month': 24, 'market': 24, 'light': 24, 'ass': 24, 'report': 24, 'dead': 24, 'wear': 24, 'who': 24, 'smoke': 24, 'behind': 24, 'transform': 24, 'desk': 24, 'stuff': 23, 'side': 23, 'bit': 23, 'photo': 23, 'with': 23, 'be': 23, 'artist': 23, 'went': 23, 'die': 23, 'told': 23, 'can': 23, 'enough': 23, 'cut': 23, 'have': 23, 'digit': 23, 'for': 23, 'style': 23, 'must': 23, 'seen': 23, 'lose': 23, 'soon': 23, 'grow': 22, 'seem': 22, 'sound': 22, 'anyon': 22, 'anoth': 22, 'm': 22, 'hot': 22, 'pretti': 22, 'goe': 22, 'kill': 22, 'chill': 22, 'hell': 22, 'here': 22, 'babi': 22, 'meet': 22, 'join': 22, 'ya': 22, 'birthday ...

# %%
# Sorting the Dictionary with the Values in Descending Order
{k: v for k, v in sorted(words_M.items(), key=lambda item: item[1], reverse =True )}
# Out:
# {'i': 1460,
#  'co': 1351,
#  'http': 1338,
#  'the': 524,
#  'get': 301,
#  'like': 278,
#  'go': 212,
#  'and': 207,
#  'one': 197,
#  'time': 185,
#  'make': 159,
#  'new': 158,
#  'love': 158,
#  'it': 146,
#  'day': 138,
#  'look': 136,
#  'you': 136,
#  'see': 135,
#  'peopl': 134,
#  'know': 132,
#  'good': 123,
#  'think': 123,
#  'want': 116,
#  'back': 114,
#  'got': 113,
#  'need': 113,
#  'best': 108,
#  'amp': 105,
#  'fuck': 104,
#  'game': 103,
#  'u': 103,
#  'say': 102,
#  'come': 102,
#  'year': 100,
#  'still': 99,
#  'thank': 97,
#  'a': 95,
#  'thing': 94,
#  'if': 94,
#  'work': 94,
#  'follow': 92,
#  'would': 92,
#  'great': 88,
#  'way': 85,
#  'play': 85,
#  'let': 82,
#  'last': 82,
#  'realli': 81,
#  'use': 80,
#  'lol': 80,
#  'via': 79,
#  'tri': 74,
#  'today': 73,
#  'take': 72,
#  'life': 72,
#  'shit': 71,
#  'well': 70,
#  'start': 69,
#  'even': 68,
#  'man': 68,
#  'first': 68,
#  'live': 67,
#  'world': 67,
#  'feel': 67,
#  'week': 66,
#  'watch': 65,
#  'next': 65,
#  'my': 64,
#  'hope': 63,
#  'that': 62,
#  'we': 62,
#  'alway': 62,
#  'right': 61,
#  'never': 61,
#  'much': 61,
#  'could': 61,
#  'in': 59,
#  'guy': 59,
#  'video': 58,
#  'just': 58,
#  'chang': 57,
#  'so': 57,
#  'what': 57,
#  'end': 57,
#  'he': 56,
#  'keep': 56,
#  'us': 55,
#  'made': 55,
#  'tell': 54,
#  'im': 53,
#  'show': 53,
#  'b': 53,
#  'win': 52,
#  'better': 52,
#  'of': 52,
#  'call': 52,
#  'when': 51,
#  'give': 51,
#  'ever': 51,
#  'also': 50,
#  'x': 50,
#  'night': 49,
#  'w': 49,
#  'big': 48,
#  'read': 48,
#  'lot': 48,
#  'nigga': 48,
#  'to': 47,
#  'someon': 47,
#  'music': 47,
#  'everi': 47,
#  'is': 47,
#  'talk': 47,
#  'friend': 46,
#  'no': 46,
#  'how': 46,
#  'gonna': 46,
#  'put': 46,
#  'ask': 46,
#  'stop': 45,
#  'v': 45,
#  'thi': 45,
#  'l': 44,
#  'real': 44,
#  'r': 44,
#  'eat': 44,
#  'c': 44,
#  'gt': 44,
#  'th': 44,
#  'team': 44,
#  'f': 44,
#  'build': 44,
#  'hous': 44,
#  'all': 43,
#  'mean': 43,
#  'two': 43,
#  'god': 43,
#  'song': 43,
#  'p': 42,
#  'word': 42,
#  'check': 42,
#  'someth': 42,
#  'but': 42,
#  'around': 42,
#  'person': 42,
#  'season': 41,
#  'rememb': 41,
#  'said': 41,
#  'k': 40,
#  'run': 40,
#  'happi': 40,
#  'n': 39,
#  'whi': 39,
#  'wonder': 39,
#  'home': 39,
#  'h': 38,
#  'mani': 38,
#  'there': 38,
#  'happen': 38,
#  'free': 38,
#  'car': 38,
#  'miss': 38,
#  'help': 38,
#  'girl': 37,
#  'find': 37,
#  'ye': 37,
#  'everyth': 37,
#  'pleas': 37,
#  'money': 37,
#  'thought': 37,
#  'e': 36,
#  'tweet': 36,
#  'noth': 36,
#  'wait': 36,
#  'boy': 36,
#  'alreadi': 36,
#  'point': 35,
#  'kid': 35,
#  'listen': 35,
#  'oh': 35,
#  'move': 35,
#  'on': 34,
#  'they': 34,
#  'hour': 34,
#  'half': 34,
#  'hate': 34,
#  'place': 34,
#  'not': 34,
#  'caus': 33,
#  'tonight': 33,
#  'yeah': 33,
#  'done': 33,
#  'everyon': 33,
#  'your': 33,
#  'halloween': 33,
#  'busi': 33,
#  'turn': 33,
#  'job': 32,
#  'd': 32,
#  'hit': 32,
#  'sure': 32,
#  'j': 32,
#  'long': 32,
#  'state': 32,
#  'nice': 32,
#  'old': 32,
#  'walk': 32,
#  'vote': 32,
#  'phone': 31,
#  'post': 31,
#  'book': 31,
#  'z': 31,
#  'unit': 31,
#  'lord': 31,
#  'app': 30,
#  'amaz': 30,
#  'enjoy': 30,
#  'g': 30,
#  'school': 30,
#  'yet': 30,
#  'head': 30,
#  'twitter': 30,
#  't': 29,
#  'without': 29,
#  'differ': 29,
#  'support': 29,
#  'player': 29,
#  'away': 29,
#  'dream': 29,
#  'bitch': 29,
#  'fan': 28,
#  'now': 28,
#  'parti': 28,
#  'drive': 28,
#  'youtub': 28,
#  'tomorrow': 28,
#  'quot': 28,
#  'probabl': 28,
#  'part': 28,
#  'stori': 27,
#  'face': 27,
#  'white': 27,
#  'excit': 27,
#  'fun': 27,
#  'bad': 27,
#  'me': 27,
#  'top': 27,
#  'believ': 27,
#  'problem': 27,
#  'hand': 27,
#  'hi': 26,
#  'past': 26,
#  'open': 26,
#  'sinc': 26,
#  'sit': 26,
#  'leav': 26,
#  'bring': 26,
#  'found': 26,
#  's': 26,
#  'brother': 26,
#  'becom': 26,
#  'buy': 26,
#  'don': 25,
#  'high': 25,
#  'littl': 25,
#  'pick': 25,
#  'set': 25,
#  'whole': 25,
#  'beauti': 25,
#  'name': 25,
#  'class': 25,
#  'space': 25,
#  'may': 25,
#  'final': 25,
#  'might': 25,
#  'actual': 25,
#  'stay': 25,
#  'learn': 24,
#  'star': 24,
#  'though': 24,
#  'month': 24,
#  'market': 24,
#  'light': 24,
#  'ass': 24,
#  'report': 24,
#  'dead': 24,
#  'wear': 24,
#  'who': 24,
#  'smoke': 24,
#  'behind': 24,
#  'transform': 24,
#  'desk': 24,
#  'stuff': 23,
#  'side': 23,
#  'bit': 23,
#  'photo': 23,
#  'with': 23,
#  'be': 23,
#  'artist': 23,
#  'went': 23,
#  'die': 23,
#  'told': 23,
#  'can': 23,
#  'enough': 23,
#  'cut': 23,
#  'have': 23,
#  'digit': 23,
#  'for': 23,
#  'style': 23,
#  'must': 23,
#  'seen': 23,
#  'lose': 23,
#  'soon': 23,
#  'grow': 22,
#  'seem': 22,
#  'sound': 22,
#  'anyon': 22,
#  'anoth': 22,
#  'm': 22,
#  'hot': 22,
#  'pretti': 22,
#  'goe': 22,
#  'kill': 22,
#  'chill': 22,
#  'hell': 22,
#  'here': 22,
#  'babi': 22,
#  'meet': 22,
#  'join': 22,
#  'ya': 22,
#  'birthday': 22,
#  'meat': 22,
#  'storag': 22,
#  'club': 21,
#  'anyth': 21,
#  'minut': 21,
#  'q': 21,
#  'sign': 21,
#  'drop': 21,
#  'citi': 21,
#  'idea': 21,
#  'wanna': 21,
#  'food': 21,
#  'wrong': 21,
#  'hear': 21,
#  'dude': 21,
#  'workbench': 21,
#  'road': 20,
#  'link': 20,
#  'process': 20,
#  'funni': 20,
#  'unfollow': 20,
#  'weekend': 20,
#  'st': 20,
#  'o': 20,
#  'coach': 20,
#  'harri': 20,
#  'young': 20,
#  'yo': 20,
#  'pay': 20,
#  'agre': 20,
#  'gone': 20,
#  'line': 20,
#  'footbal': 20,
#  'lie': 20,
#  'cup': 20,
#  'she': 20,
#  'moment': 20,
#  'deal': 20,
#  'saw': 20,
#  'wow': 20,
#  'bond': 19,
#  'spectr': 19,
#  'fall': 19,
#  'black': 19,
#  'chanc': 19,
#  'will': 19,
#  'from': 19,
#  'pull': 19,
#  'definit': 19,
#  'park': 19,
#  'futur': 19,
#  'pic': 19,
#  'cancer': 19,
#  'news': 19,
#  'at': 19,
#  'million': 19,
#  'took': 19,
#  'full': 19,
#  'movi': 19,
#  'pictur': 19,
#  'as': 19,
#  'stat': 18,
#  'dark': 18,
#  'matter': 18,
#  'nba': 18,
#  'readi': 18,
#  'credit': 18,
#  'hold': 18,
#  'plan': 18,
#  'care': 18,
#  'room': 18,
#  'monday': 18,
#  'train': 18,
#  'ok': 18,
#  'morn': 18,
#  'y': 18,
#  'tax': 18,
#  'ladi': 18,
#  'bro': 18,
#  'visit': 18,
#  'eye': 18,
#  'gotta': 18,
#  'smile': 18,
#  'share': 18,
#  'human': 18,
#  'vs': 18,
#  'winter': 18,
#  'mind': 18,
#  'second': 18,
#  'cool': 18,
#  'street': 17,
#  'fact': 17,
#  'issu': 17,
#  'truth': 17,
#  'sell': 17,
#  'perfect': 17,
#  'date': 17,
#  'drink': 17,
#  'tv': 17,
#  'laugh': 17,
#  'send': 17,
#  'ball': 17,
#  'episod': 17,
#  'dont': 17,
#  'servic': 17,
#  'kind': 17,
#  'charact': 17,
#  'written': 17,
#  'nation': 17,
#  'reason': 17,
#  'lmao': 17,
#  'act': 17,
#  'close': 17,
#  'mayb': 17,
#  'true': 17,
#  'bless': 17,
#  'fire': 17,
#  'interest': 17,
#  'uk': 16,
#  'retweet': 16,
#  'less': 16,
#  'facebook': 16,
#  'came': 16,
#  'along': 16,
#  'goal': 16,
#  'stupid': 16,
#  'mom': 16,
#  'hello': 16,
#  'fund': 16,
#  'group': 16,
#  'worst': 16,
#  'els': 16,
#  'onedirect': 16,
#  'round': 16,
#  'wish': 16,
#  'low': 16,
#  'number': 16,
#  'situat': 16,
#  'favorit': 16,
#  'rock': 16,
#  'ago': 16,
#  'fight': 16,
#  'pass': 16,
#  'realiz': 16,
#  'product': 16,
#  'dog': 16,
#  'album': 16,
#  'do': 16,
#  'trump': 16,
#  'heart': 16,
#  'min': 16,
#  'fulani': 16,
#  'save': 16,
#  'ticket': 16,
#  'delay': 16,
#  'sorri': 16,
#  'leagu': 16,
#  'beat': 16,
#  'hair': 16,
#  'manag': 16,
#  'student': 16,
#  'jame': 15,
#  'daili': 15,
#  'account': 15,
#  'stand': 15,
#  'where': 15,
#  'damn': 15,
#  'bout': 15,
#  'pm': 15,
#  'celebr': 15,
#  'film': 15,
#  'possibl': 15,
#  'awesom': 15,
#  'posit': 15,
#  'onli': 15,
#  'taxcredit': 15,
#  'impud': 15,
#  'rabiu': 15,
#  'kwakwanso': 15,
#  'ffk': 15,
#  'femi': 15,
#  'fani': 15,
#  'kayod': 15,
#  'price': 15,
#  'are': 15,
#  'question': 15,
#  'left': 15,
#  'ruin': 15,
#  'success': 15,
#  'john': 15,
#  'sad': 15,
#  'ur': 15,
#  'largest': 14,
#  'did': 14,
#  'media': 14,
#  'test': 14,
#  'elect': 14,
#  'glad': 14,
#  'voic': 14,
#  'ama': 14,
#  'releas': 14,
#  'offic': 14,
#  'write': 14,
#  'draw': 14,
#  'ad': 14,
#  'fake': 14,
#  'paper': 14,
#  'forget': 14,
#  'hard': 14,
#  'data': 14,
#  'despit': 14,
#  'heard': 14,
#  'countri': 14,
#  'tag': 14,
#  'met': 14,
#  'smh': 14,
#  'struggl': 14,
#  'mad': 14,
#  'break': 14,
#  'return': 14,
#  'complet': 14,
#  'either': 14,
#  'some': 14,
#  'system': 14,
#  'quit': 14,
#  'catch': 14,
#  'respect': 14,
#  'histori': 14,
#  'talent': 14,
#  'power': 14,
#  'finish': 14,
#  'given': 14,
#  'blog': 14,
#  'saturday': 14,
#  'art': 14,
#  'up': 13,
#  'famili': 13,
#  'blame': 13,
#  'entir': 13,
#  'red': 13,
#  'appl': 13,
#  'answer': 13,
#  'front': 13,
#  'ppl': 13,
#  'track': 13,
#  'crazi': 13,
#  'friday': 13,
#  'record': 13,
#  'forward': 13,
#  'recent': 13,
#  'control': 13,
#  'fail': 13,
#  'guess': 13,
#  'netflix': 13,
#  'speak': 13,
#  'interview': 13,
#  'wast': 13,
#  'step': 13,
#  'lead': 13,
#  'sweet': 13,
#  'mobil': 13,
#  'practic': 13,
#  'cri': 13,
#  'wa': 13,
#  'wood': 13,
#  'paid': 13,
#  'sport': 13,
#  'blue': 13,
#  'defens': 13,
#  'base': 12,
#  'match': 12,
#  'yesterday': 12,
#  'greatest': 12,
#  'or': 12,
#  'fantast': 12,
#  'off': 12,
#  'scene': 12,
#  'easi': 12,
#  'shop': 12,
#  'costum': 12,
#  'comment': 12,
#  'plu': 12,
#  'soul': 12,
#  'fine': 12,
#  'cant': 12,
#  'wors': 12,
#  'earth': 12,
#  'danc': 12,
#  'bacon': 12,
#  'lost': 12,
#  'candi': 12,
#  'sometim': 12,
#  'other': 12,
#  'review': 12,
#  'onlin': 12,
#  'deserv': 12,
#  'blood': 12,
#  'fix': 12,
#  'remind': 12,
#  'experi': 12,
#  'till': 12,
#  'king': 12,
#  'shirt': 12,
#  'liter': 12,
#  'strong': 12,
#  'straight': 12,
#  'inform': 12,
#  'trust': 12,
#  'folk': 12,
#  'articl': 12,
#  'then': 12,
#  'cover': 12,
#  'welcom': 12,
#  'push': 12,
#  'bed': 12,
#  'trade': 12,
#  'budget': 12,
#  'sleep': 12,
#  'fit': 12,
#  'women': 12,
#  'door': 12,
#  'taken': 11,
#  'suck': 11,
#  'roll': 11,
#  'expect': 11,
#  'polit': 11,
#  'develop': 11,
#  'note': 11,
#  'shut': 11,
#  'knew': 11,
#  'drug': 11,
#  'industri': 11,
#  'coupl': 11,
#  'total': 11,
#  'joke': 11,
#  'nd': 11,
#  'wall': 11,
#  'block': 11,
#  'monster': 11,
#  'pray': 11,
#  'decid': 11,
#  'burn': 11,
#  'compani': 11,
#  'bust': 11,
#  'chat': 11,
#  'far': 11,
#  'import': 11,
#  'gospel': 11,
#  'later': 11,
#  'gym': 11,
#  'short': 11,
#  'middl': 11,
#  'cold': 11,
#  'piec': 11,
#  'cute': 11,
#  'woman': 11,
#  'rule': 11,
#  'dad': 11,
#  'featur': 11,
#  'instead': 11,
#  'forc': 11,
#  'cours': 11,
#  'tech': 11,
#  'out': 11,
#  'case': 11,
#  'anymor': 11,
#  'hahaha': 11,
#  'insid': 11,
#  'shot': 11,
#  'pink': 11,
#  'femal': 11,
#  'organ': 11,
#  'special': 11,
#  'order': 11,
#  'almost': 11,
#  'type': 11,
#  'sunday': 11,
#  'offici': 11,
#  'govern': 11,
#  'kiss': 11,
#  'canada': 11,
#  'inspir': 11,
#  'appar': 11,
#  'podcast': 11,
#  'hey': 11,
#  'scari': 11,
#  'gain': 11,
#  'band': 11,
#  'about': 11,
#  'men': 11,
#  'water': 11,
#  'mike': 11,
#  'clean': 11,
#  'doctor': 11,
#  'instagram': 11,
#  'after': 10,
#  'least': 10,
#  'wednesday': 10,
#  'count': 10,
#  'him': 10,
#  'christian': 10,
#  'togeth': 10,
#  'launch': 10,
#  'except': 10,
#  'bc': 10,
#  'huge': 10,
#  'view': 10,
#  'comput': 10,
#  'social': 10,
#  'rest': 10,
#  'googl': 10,
#  'stream': 10,
#  'appreci': 10,
#  'air': 10,
#  'shoot': 10,
#  'yr': 10,
#  'leader': 10,
#  'spot': 10,
#  'teacher': 10,
#  'bodi': 10,
#  'em': 10,
#  'cross': 10,
#  'jesu': 10,
#  'octob': 10,
#  'poor': 10,
#  'cop': 10,
#  'earli': 10,
#  'south': 10,
#  'studi': 10,
#  'project': 10,
#  'page': 10,
#  'bill': 10,
#  'super': 10,
#  'mr': 10,
#  'promot': 10,
#  'dick': 10,
#  'schedul': 10,
#  'age': 10,
#  'ah': 10,
#  'an': 10,
#  'continu': 10,
#  'mate': 10,
#  'american': 10,
#  'sale': 10,
#  'health': 10,
#  'mother': 10,
#  'bar': 10,
#  'small': 10,
#  'secur': 10,
#  'chip': 10,
#  'fair': 10,
#  'pl': 10,
#  'educ': 10,
#  'nap': 10,
#  'holiday': 10,
#  'lil': 10,
#  'add': 10,
#  'surpris': 10,
#  'internet': 10,
#  'ride': 10,
#  'scienc': 10,
#  'too': 10,
#  'incred': 10,
#  'memori': 10,
#  'pack': 10,
#  'children': 10,
#  'list': 10,
#  'tire': 10,
#  'three': 10,
#  'begin': 10,
#  'rate': 10,
#  'pen': 10,
#  'neg': 10,
#  'hug': 10,
#  'tip': 10,
#  'offens': 10,
#  'haha': 9,
#  'everyday': 9,
#  'rais': 9,
#  'email': 9,
#  'convers': 9,
#  'clear': 9,
#  'piss': 9,
#  'wale': 9,
#  'greed': 9,
#  'america': 9,
#  'thisiswhyweplay': 9,
#  'updat': 9,
#  'site': 9,
#  'contest': 9,
#  'current': 9,
#  'christma': 9,
#  'law': 9,
#  'third': 9,
#  'consid': 9,
#  'np': 9,
#  'screen': 9,
#  'bu': 9,
#  'basketbal': 9,
#  'paul': 9,
#  'secret': 9,
#  'websit': 9,
#  'fast': 9,
#  'worri': 9,
#  'amount': 9,
#  'score': 9,
#  'competit': 9,
#  'spend': 9,
#  'copi': 9,
#  'ring': 9,
#  'fear': 9,
#  'annoy': 9,
#  'bowl': 9,
#  'allow': 9,
#  'seriou': 9,
#  'parent': 9,
#  'tast': 9,
#  'worth': 9,
#  'biggest': 9,
#  'late': 9,
#  'store': 9,
#  'everybodi': 9,
#  'labour': 9,
#  'diamond': 9,
#  'auction': 9,
#  'pain': 9,
#  'pro': 9,
#  'himself': 9,
#  'argu': 9,
#  'latest': 9,
#  'motion': 9,
#  'card': 9,
#  'concert': 9,
#  'vibe': 9,
#  'taylor': 9,
#  'pressur': 9,
#  'rich': 9,
#  'pussi': 9,
#  'our': 9,
#  'hardi': 9,
#  'forev': 9,
#  'bank': 9,
#  'produc': 9,
#  'kick': 9,
#  'comic': 9,
#  'mention': 9,
#  'charg': 9,
#  'father': 9,
#  'mix': 9,
#  'blow': 9,
#  'across': 9,
#  'wisdom': 9,
#  'anim': 9,
#  'cat': 9,
#  'fli': 9,
#  'prove': 9,
#  'bag': 9,
#  'hop': 9,
#  'challeng': 9,
#  'pat': 9,
#  'staff': 9,
#  'tho': 9,
#  'includ': 9,
#  'cre': 9,
#  'critic': 8,
#  'bought': 8,
#  'yall': 8,
#  'premier': 8,
#  'gave': 8,
#  'suppos': 8,
#  'abl': 8,
#  'id': 8,
#  'touch': 8,
#  'five': 8,
#  'militari': 8,
#  'arriv': 8,
#  'queen': 8,
#  'cc': 8,
#  'should': 8,
#  'sweepstak': 8,
#  'shout': 8,
#  'sent': 8,
#  'floor': 8,
#  'safe': 8,
#  'ignor': 8,
#  'race': 8,
#  'dear': 8,
#  'hang': 8,
#  'cowboy': 8,
#  'ill': 8,
#  'cook': 8,
#  'choos': 8,
#  'china': 8,
#  'rank': 8,
#  'wake': 8,
#  'technolog': 8,
#  'novemb': 8,
#  'summer': 8,
#  'hillari': 8,
#  'jack': 8,
#  'valu': 8,
#  'entrepreneur': 8,
#  'understand': 8,
#  'tori': 8,
#  'wit': 8,
#  'healthi': 8,
#  'which': 8,
#  'colleg': 8,
#  'fill': 8,
#  'alon': 8,
#  'local': 8,
#  'notic': 8,
#  'defend': 8,
#  'rare': 8,
#  'zombi': 8,
#  'illinoi': 8,
#  'north': 8,
#  'apolog': 8,
#  'throw': 8,
#  'ice': 8,
#  'main': 8,
#  'more': 8,
#  'mask': 8,
#  'bruh': 8,
#  'ff': 8,
#  'boss': 8,
#  'drake': 8,
#  'whatev': 8,
#  'creativ': 8,
#  'connect': 8,
#  'lucki': 8,
#  'london': 8,
#  'holi': 8,
#  'imagin': 8,
#  'dope': 8,
#  'compar': 8,
#  'el': 8,
#  'soundcloud': 8,
#  'chicken': 8,
#  'tour': 8,
#  'leg': 8,
#  'doubt': 8,
#  'mental': 8,
#  'present': 8,
#  'perform': 8,
#  'becaus': 8,
#  'knock': 8,
#  'okay': 8,
#  'scare': 8,
#  'smith': 8,
#  'chief': 8,
#  'brand': 8,
#  'lt': 8,
#  'level': 8,
#  'carri': 8,
#  'honestli': 8,
#  'earn': 8,
#  'quiet': 8,
#  'progress': 8,
#  'luck': 8,
#  'proud': 8,
#  'singl': 8,
#  'sardar': 8,
#  'biglari': 8,
#  'lousi': 8,
#  'danger': 8,
#  'dress': 8,
#  'network': 8,
#  'brilliant': 8,
#  ...}

# %% [markdown]
# #### So,From the above calculation,
# ###### The Most Common WORD  used by Males is "I" which was used 1460 times !
# ###### The most Common EMOTION used by Males is "love" which was used 158 times !!
#
# #### 1.b For Females

# %%
# Taking only those rows with gender as "Female"

X_info_F = X_information.loc[ (X_information.gender == "female" )]

# %%
X_info_F.head()
# Out:
#     gender           name                                       cleaned_text  \
# 4   female   WilfordGemma           watch neighbour ski catch neighb xxx xxx
# 5   female  monroevicious  ive seen peopl train lamp chair tv etc http co...
# 8   female      pigzilla_  aphmau pic defin mcd fangirl fanboy mcd shippe...
# 9   female  GabrieleNeher  evieladi love tree year never seen gorgeou aut...
# 16  female   Toucaan_Samm  giannaaa lmao dude i hella scare next episod b...
#
#                                   cleaned_description
# 4   ricki wilson the best frontman kaiser chief th...
# 5                                                know
# 8                         pll fan crazi mcd ramen bae
# 9   renaiss art historian univers nottingham fuell...
# 16                                               jmkm

# %%
# Instantiating the Counter.
words_F = Counter()

# Taking the column named "cleaned_text" and counting the frequency of each word.
X_info_F['cleaned_text'].str.split().apply(words_F.update)

print(words_F)
# Out:
# Counter({'i': 2311, 'co': 1380, 'http': 1373, 'the': 438, 'get': 336, 'like': 329, 'and': 305, 'go': 282, 'love': 275, 'day': 263, 'one': 260, 'time': 207, 'peopl': 181, 'make': 176, 'want': 168, 'know': 159, 'u': 149, 'look': 145, 'you': 144, 'amp': 144, 'thank': 143, 'got': 140, 'it': 140, 'new': 139, 'best': 137, 'need': 132, 'thing': 129, 'good': 128, 'my': 126, 'see': 125, 'work': 125, 'still': 125, 'follow': 123, 'say': 121, 'think': 119, 'so': 118, 'back': 118, 'come': 115, 'even': 111, 'take': 107, 'today': 107, 'tri': 106, 'just': 105, 'fuck': 105, 'feel': 104, 'life': 104, 'watch': 103, 'girl': 102, 'lol': 101, 'year': 99, 'right': 99, 'thi': 93, 'friend': 93, 'happi': 91, 'never': 89, 'when': 89, 'realli': 88, 'a': 87, 'much': 86, 'ever': 86, 'im': 86, 'would': 85, 'vote': 85, 'way': 84, 'shit': 83, 'let': 82, 'last': 79, 'person': 79, 'home': 78, 'live': 77, 'world': 76, 'alway': 76, 'talk': 74, 'first': 72, 'week': 71, 'use': 71, 'help': 70, 'show': 68, 'made': 65, 'if': 65, 'call': 65, 'that': 65, 'someon': 64, 'gonna': 64, 'wait': 63, 'w': 62, 'x': 62, 'give': 62, 'well': 61, 'miss': 60, 'put': 60, 'start': 59, 'what': 59, 'tell': 59, 'better': 58, 'night': 57, 'littl': 57, 'school': 57, 'guy': 56, 'b': 56, 'via': 56, 'hope': 56, 'ask': 56, 'said': 55, 'next': 54, 'pleas': 54, 'is': 54, 'onedirect': 54, 'hate': 54, 'but': 54, 'favorit': 54, 'great': 53, 'find': 53, 'eat': 53, 'check': 53, 'us': 52, 'in': 52, 'of': 52, 'class': 52, 'beauti': 52, 'halloween': 51, 'could': 51, 'wanna': 51, 'lot': 51, 'video': 50, 'cri': 50, 'everyth': 50, 'to': 49, 'phone': 49, 'sit': 49, 'play': 49, 'everi': 49, 'hous': 48, 'listen': 48, 'two': 48, 'kid': 47, 'die': 47, 'thought': 47, 'someth': 47, 'n': 46, 'they': 46, 'famili': 46, 'we': 46, 'man': 46, 'hair': 46, 'heart': 46, 'car': 46, 'all': 45, 'p': 45, 'meet': 45, 'actual': 45, 'mani': 45, 'real': 45, 'stop': 45, 'oh': 45, 'how': 45, 'everyon': 45, 'read': 44, 'differ': 44, 'around': 44, 'noth': 44, 'walk': 44, 'keep': 44, 'me': 43, 'amaz': 43, 'no': 43, 'past': 43, 'black': 43, 'food': 43, 'g': 43, 'bc': 42, 'end': 42, 'god': 42, 'liter': 42, 'care': 42, 'here': 42, 'bad': 41, 'k': 41, 'mom': 41, 'mind': 41, 'went': 40, 'hour': 40, 'song': 40, 'word': 40, 'can': 40, 'caus': 40, 'birthday': 39, 'ama': 39, 'also': 39, 'done': 38, 'wish': 38, 'h': 38, 'tomorrow': 38, 'win': 38, 'unfollow': 38, 'boy': 37, 'room': 37, 'mean': 37, 'away': 37, 'hard': 37, 'th': 37, 'ass': 37, 'she': 37, 'leav': 36, 'be': 36, 'bed': 36, 'e': 36, 'ye': 36, 'half': 36, 'game': 36, 'alreadi': 36, 'old': 36, 'music': 36, 'found': 35, 'bitch': 35, 'excit': 35, 'do': 35, 's': 35, 'stay': 35, 'month': 34, 'face': 34, 'z': 34, 'post': 34, 'fun': 34, 'rememb': 34, 'turn': 34, 'for': 34, 'sure': 34, 'dress': 34, 'weekend': 34, 'final': 34, 'monday': 34, 'cute': 34, 'nice': 33, 'move': 33, 'r': 33, 'chang': 33, 'pictur': 33, 'on': 33, 'are': 33, 'eye': 33, 'photo': 32, 'artistoftheyear': 32, 'ur': 32, 'harri': 32, 'fall': 32, 'q': 32, 'sad': 32, 'whole': 32, 'c': 32, 'wrong': 31, 'd': 31, 'v': 31, 'whi': 31, 'money': 31, 'name': 31, 'sleep': 30, 'part': 30, 'happen': 30, 'saw': 30, 'readi': 30, 'togeth': 30, 'gt': 30, 'may': 30, 'movi': 29, 'book': 29, 'open': 29, 'wear': 29, 'dead': 29, 'damn': 29, 'yeah': 29, 'busi': 29, 'm': 29, 'there': 29, 'tweet': 29, 'big': 29, 'lmao': 28, 'build': 28, 'tonight': 28, 'long': 28, 'parti': 28, 'he': 28, 'women': 28, 'not': 28, 'free': 28, 'fight': 28, 'anyth': 27, 'f': 27, 'took': 27, 'ticket': 27, 'j': 27, 'break': 27, 'style': 27, 'dad': 27, 'cut': 27, 'stori': 27, 'have': 27, 'moment': 27, 'mayb': 27, 'run': 27, 'problem': 27, 'told': 27, 'seen': 26, 'job': 26, 'enjoy': 26, 'grow': 26, 'wonder': 26, 'bless': 26, 'place': 26, 'dream': 26, 'head': 26, 'buy': 26, 'reason': 26, 'l': 25, 'worst': 25, 'fact': 25, 'left': 25, 'hi': 25, 'twitter': 25, 'anoth': 25, 'kind': 25, 'high': 25, 'probabl': 25, 'omg': 25, 'babi': 25, 'realiz': 25, 'app': 24, 'without': 24, 'artist': 2 ...

# %%
# Sorting the Dictionary with the Values in Descending Order
{k: v for k, v in sorted(words_F.items(), key=lambda item: item[1], reverse =True )}
# Out:
# {'i': 2311,
#  'co': 1380,
#  'http': 1373,
#  'the': 438,
#  'get': 336,
#  'like': 329,
#  'and': 305,
#  'go': 282,
#  'love': 275,
#  'day': 263,
#  'one': 260,
#  'time': 207,
#  'peopl': 181,
#  'make': 176,
#  'want': 168,
#  'know': 159,
#  'u': 149,
#  'look': 145,
#  'you': 144,
#  'amp': 144,
#  'thank': 143,
#  'got': 140,
#  'it': 140,
#  'new': 139,
#  'best': 137,
#  'need': 132,
#  'thing': 129,
#  'good': 128,
#  'my': 126,
#  'see': 125,
#  'work': 125,
#  'still': 125,
#  'follow': 123,
#  'say': 121,
#  'think': 119,
#  'so': 118,
#  'back': 118,
#  'come': 115,
#  'even': 111,
#  'take': 107,
#  'today': 107,
#  'tri': 106,
#  'just': 105,
#  'fuck': 105,
#  'feel': 104,
#  'life': 104,
#  'watch': 103,
#  'girl': 102,
#  'lol': 101,
#  'year': 99,
#  'right': 99,
#  'thi': 93,
#  'friend': 93,
#  'happi': 91,
#  'never': 89,
#  'when': 89,
#  'realli': 88,
#  'a': 87,
#  'much': 86,
#  'ever': 86,
#  'im': 86,
#  'would': 85,
#  'vote': 85,
#  'way': 84,
#  'shit': 83,
#  'let': 82,
#  'last': 79,
#  'person': 79,
#  'home': 78,
#  'live': 77,
#  'world': 76,
#  'alway': 76,
#  'talk': 74,
#  'first': 72,
#  'week': 71,
#  'use': 71,
#  'help': 70,
#  'show': 68,
#  'made': 65,
#  'if': 65,
#  'call': 65,
#  'that': 65,
#  'someon': 64,
#  'gonna': 64,
#  'wait': 63,
#  'w': 62,
#  'x': 62,
#  'give': 62,
#  'well': 61,
#  'miss': 60,
#  'put': 60,
#  'start': 59,
#  'what': 59,
#  'tell': 59,
#  'better': 58,
#  'night': 57,
#  'littl': 57,
#  'school': 57,
#  'guy': 56,
#  'b': 56,
#  'via': 56,
#  'hope': 56,
#  'ask': 56,
#  'said': 55,
#  'next': 54,
#  'pleas': 54,
#  'is': 54,
#  'onedirect': 54,
#  'hate': 54,
#  'but': 54,
#  'favorit': 54,
#  'great': 53,
#  'find': 53,
#  'eat': 53,
#  'check': 53,
#  'us': 52,
#  'in': 52,
#  'of': 52,
#  'class': 52,
#  'beauti': 52,
#  'halloween': 51,
#  'could': 51,
#  'wanna': 51,
#  'lot': 51,
#  'video': 50,
#  'cri': 50,
#  'everyth': 50,
#  'to': 49,
#  'phone': 49,
#  'sit': 49,
#  'play': 49,
#  'everi': 49,
#  'hous': 48,
#  'listen': 48,
#  'two': 48,
#  'kid': 47,
#  'die': 47,
#  'thought': 47,
#  'someth': 47,
#  'n': 46,
#  'they': 46,
#  'famili': 46,
#  'we': 46,
#  'man': 46,
#  'hair': 46,
#  'heart': 46,
#  'car': 46,
#  'all': 45,
#  'p': 45,
#  'meet': 45,
#  'actual': 45,
#  'mani': 45,
#  'real': 45,
#  'stop': 45,
#  'oh': 45,
#  'how': 45,
#  'everyon': 45,
#  'read': 44,
#  'differ': 44,
#  'around': 44,
#  'noth': 44,
#  'walk': 44,
#  'keep': 44,
#  'me': 43,
#  'amaz': 43,
#  'no': 43,
#  'past': 43,
#  'black': 43,
#  'food': 43,
#  'g': 43,
#  'bc': 42,
#  'end': 42,
#  'god': 42,
#  'liter': 42,
#  'care': 42,
#  'here': 42,
#  'bad': 41,
#  'k': 41,
#  'mom': 41,
#  'mind': 41,
#  'went': 40,
#  'hour': 40,
#  'song': 40,
#  'word': 40,
#  'can': 40,
#  'caus': 40,
#  'birthday': 39,
#  'ama': 39,
#  'also': 39,
#  'done': 38,
#  'wish': 38,
#  'h': 38,
#  'tomorrow': 38,
#  'win': 38,
#  'unfollow': 38,
#  'boy': 37,
#  'room': 37,
#  'mean': 37,
#  'away': 37,
#  'hard': 37,
#  'th': 37,
#  'ass': 37,
#  'she': 37,
#  'leav': 36,
#  'be': 36,
#  'bed': 36,
#  'e': 36,
#  'ye': 36,
#  'half': 36,
#  'game': 36,
#  'alreadi': 36,
#  'old': 36,
#  'music': 36,
#  'found': 35,
#  'bitch': 35,
#  'excit': 35,
#  'do': 35,
#  's': 35,
#  'stay': 35,
#  'month': 34,
#  'face': 34,
#  'z': 34,
#  'post': 34,
#  'fun': 34,
#  'rememb': 34,
#  'turn': 34,
#  'for': 34,
#  'sure': 34,
#  'dress': 34,
#  'weekend': 34,
#  'final': 34,
#  'monday': 34,
#  'cute': 34,
#  'nice': 33,
#  'move': 33,
#  'r': 33,
#  'chang': 33,
#  'pictur': 33,
#  'on': 33,
#  'are': 33,
#  'eye': 33,
#  'photo': 32,
#  'artistoftheyear': 32,
#  'ur': 32,
#  'harri': 32,
#  'fall': 32,
#  'q': 32,
#  'sad': 32,
#  'whole': 32,
#  'c': 32,
#  'wrong': 31,
#  'd': 31,
#  'v': 31,
#  'whi': 31,
#  'money': 31,
#  'name': 31,
#  'sleep': 30,
#  'part': 30,
#  'happen': 30,
#  'saw': 30,
#  'readi': 30,
#  'togeth': 30,
#  'gt': 30,
#  'may': 30,
#  'movi': 29,
#  'book': 29,
#  'open': 29,
#  'wear': 29,
#  'dead': 29,
#  'damn': 29,
#  'yeah': 29,
#  'busi': 29,
#  'm': 29,
#  'there': 29,
#  'tweet': 29,
#  'big': 29,
#  'lmao': 28,
#  'build': 28,
#  'tonight': 28,
#  'long': 28,
#  'parti': 28,
#  'he': 28,
#  'women': 28,
#  'not': 28,
#  'free': 28,
#  'fight': 28,
#  'anyth': 27,
#  'f': 27,
#  'took': 27,
#  'ticket': 27,
#  'j': 27,
#  'break': 27,
#  'style': 27,
#  'dad': 27,
#  'cut': 27,
#  'stori': 27,
#  'have': 27,
#  'moment': 27,
#  'mayb': 27,
#  'run': 27,
#  'problem': 27,
#  'told': 27,
#  'seen': 26,
#  'job': 26,
#  'enjoy': 26,
#  'grow': 26,
#  'wonder': 26,
#  'bless': 26,
#  'place': 26,
#  'dream': 26,
#  'head': 26,
#  'buy': 26,
#  'reason': 26,
#  'l': 25,
#  'worst': 25,
#  'fact': 25,
#  'left': 25,
#  'hi': 25,
#  'twitter': 25,
#  'anoth': 25,
#  'kind': 25,
#  'high': 25,
#  'probabl': 25,
#  'omg': 25,
#  'babi': 25,
#  'realiz': 25,
#  'app': 24,
#  'without': 24,
#  'artist': 24,
#  'learn': 24,
#  'rest': 24,
#  'enough': 24,
#  'at': 24,
#  'believ': 24,
#  'your': 24,
#  'text': 24,
#  'hand': 24,
#  'minut': 23,
#  'hit': 23,
#  'lost': 23,
#  'late': 23,
#  't': 23,
#  'might': 23,
#  'health': 23,
#  'annoy': 23,
#  'mine': 23,
#  'perfect': 23,
#  'close': 23,
#  'pretti': 23,
#  'though': 22,
#  'futur': 22,
#  'plan': 22,
#  'with': 22,
#  'art': 22,
#  'hell': 22,
#  'sinc': 22,
#  'sorri': 22,
#  'sister': 22,
#  'send': 22,
#  'mad': 22,
#  'drive': 22,
#  'shop': 22,
#  'episod': 21,
#  'group': 21,
#  'hello': 21,
#  'light': 21,
#  'okay': 21,
#  'now': 21,
#  'cours': 21,
#  'who': 21,
#  'true': 21,
#  'pick': 21,
#  'far': 21,
#  'smile': 21,
#  'brother': 21,
#  'yet': 21,
#  'hey': 21,
#  'ppl': 21,
#  'ya': 21,
#  'cover': 21,
#  'automat': 21,
#  'side': 20,
#  'film': 20,
#  'hear': 20,
#  'sometim': 20,
#  'parent': 20,
#  'goal': 20,
#  'worth': 20,
#  'visit': 20,
#  'nigga': 20,
#  'tho': 20,
#  'fan': 20,
#  'lt': 20,
#  'o': 20,
#  'account': 20,
#  'least': 20,
#  'bring': 20,
#  'almost': 20,
#  'power': 20,
#  'tire': 20,
#  'pic': 19,
#  'goe': 19,
#  'spend': 19,
#  'men': 19,
#  'white': 19,
#  'point': 19,
#  'don': 19,
#  'blue': 19,
#  'these': 19,
#  'understand': 19,
#  'pay': 19,
#  'sick': 19,
#  'chanc': 19,
#  'costum': 19,
#  'stuff': 19,
#  'chill': 19,
#  'dude': 18,
#  'state': 18,
#  'cool': 18,
#  'throw': 18,
#  'ago': 18,
#  'act': 18,
#  'line': 18,
#  'woman': 18,
#  'pink': 18,
#  'product': 18,
#  'drink': 18,
#  'tour': 18,
#  'proud': 18,
#  'full': 18,
#  'page': 18,
#  'test': 18,
#  'stand': 18,
#  'must': 18,
#  'y': 18,
#  'pumpkin': 18,
#  'fire': 18,
#  'ladi': 18,
#  'ok': 18,
#  'gotta': 18,
#  'hurt': 18,
#  'season': 18,
#  'cancer': 18,
#  'faliv': 18,
#  'bodi': 18,
#  'star': 18,
#  'tv': 17,
#  'yesterday': 17,
#  'suck': 17,
#  'gone': 17,
#  'lord': 17,
#  'album': 17,
#  'cat': 17,
#  'question': 17,
#  'write': 17,
#  'bu': 17,
#  'top': 17,
#  'super': 17,
#  'lie': 17,
#  'door': 17,
#  'news': 17,
#  'doctor': 17,
#  'meat': 17,
#  'later': 17,
#  'instead': 17,
#  'date': 17,
#  'stress': 17,
#  'voic': 17,
#  'hot': 17,
#  'red': 17,
#  'am': 16,
#  'idea': 16,
#  'wed': 16,
#  'justinbieb': 16,
#  'green': 16,
#  'studi': 16,
#  'interest': 16,
#  'kill': 16,
#  'blog': 16,
#  'stupid': 16,
#  'rain': 16,
#  'sound': 16,
#  'list': 16,
#  'second': 16,
#  'answer': 16,
#  'outsid': 16,
#  'number': 16,
#  'less': 16,
#  'dog': 16,
#  'funni': 16,
#  'crazi': 16,
#  'step': 16,
#  'order': 15,
#  'unit': 15,
#  'ring': 15,
#  'coupl': 15,
#  'weird': 15,
#  'teacher': 15,
#  'drop': 15,
#  'pull': 15,
#  'age': 15,
#  'price': 15,
#  'forget': 15,
#  'ride': 15,
#  'stat': 15,
#  'citi': 15,
#  'up': 15,
#  'youtub': 15,
#  'friday': 15,
#  'coffe': 15,
#  'set': 15,
#  'colleg': 15,
#  'ha': 15,
#  'issu': 15,
#  'anyon': 15,
#  'forev': 15,
#  'practic': 15,
#  'awesom': 15,
#  'enter': 15,
#  'bacon': 15,
#  'creativ': 15,
#  'short': 15,
#  'import': 15,
#  'tbh': 15,
#  'scare': 14,
#  'offic': 14,
#  'space': 14,
#  'cloth': 14,
#  'from': 14,
#  'heard': 14,
#  'hold': 14,
#  'shirt': 14,
#  'bag': 14,
#  'truth': 14,
#  'idk': 14,
#  'water': 14,
#  'els': 14,
#  'definit': 14,
#  'came': 14,
#  'dinner': 14,
#  'bathroom': 14,
#  'lunch': 14,
#  'roll': 14,
#  'everyday': 14,
#  'mouth': 14,
#  'social': 14,
#  'trust': 14,
#  'forward': 14,
#  'treat': 14,
#  'laugh': 14,
#  'desk': 14,
#  'catch': 13,
#  'retweet': 13,
#  'smell': 13,
#  'guess': 13,
#  'earli': 13,
#  'interview': 13,
#  'seem': 13,
#  'middl': 13,
#  'alon': 13,
#  'across': 13,
#  'fail': 13,
#  'homework': 13,
#  'servic': 13,
#  'wow': 13,
#  'support': 13,
#  'concert': 13,
#  'drug': 13,
#  'inspir': 13,
#  'small': 13,
#  'air': 13,
#  'where': 13,
#  'saturday': 13,
#  'outfit': 13,
#  'countri': 13,
#  'nap': 13,
#  'expect': 13,
#  'deserv': 13,
#  'sing': 13,
#  'dont': 13,
#  'spent': 13,
#  'commun': 13,
#  'sign': 13,
#  'pm': 13,
#  'singl': 13,
#  'anymor': 13,
#  'kiss': 13,
#  'facebook': 13,
#  'broke': 13,
#  'wake': 13,
#  'fell': 13,
#  'danc': 13,
#  'adel': 13,
#  'some': 13,
#  'ive': 12,
#  'onlin': 12,
#  'decid': 12,
#  'behind': 12,
#  'finish': 12,
#  'street': 12,
#  'straight': 12,
#  'tag': 12,
#  'lucki': 12,
#  'children': 12,
#  'babe': 12,
#  'morn': 12,
#  'sex': 12,
#  'human': 12,
#  'relationship': 12,
#  'ill': 12,
#  'link': 12,
#  'mood': 12,
#  'park': 12,
#  'wtf': 12,
#  'christma': 12,
#  'rock': 12,
#  'everybodi': 12,
#  'skin': 12,
#  'deal': 12,
#  'basic': 12,
#  'piec': 12,
#  'her': 12,
#  'cook': 12,
#  'cuz': 12,
#  'mother': 12,
#  'fat': 12,
#  'begin': 12,
#  'mum': 12,
#  'experi': 12,
#  'met': 12,
#  'travel': 12,
#  'other': 12,
#  'cake': 12,
#  'offer': 12,
#  'pray': 12,
#  'celebr': 12,
#  'chees': 12,
#  'boyfriend': 12,
#  'fake': 12,
#  'train': 11,
#  'floor': 11,
#  'chat': 11,
#  'uk': 11,
#  'abl': 11,
#  'secret': 11,
#  'lose': 11,
#  'too': 11,
#  'discuss': 11,
#  'honestli': 11,
#  'em': 11,
#  'size': 11,
#  'gain': 11,
#  'univers': 11,
#  'agre': 11,
#  'clean': 11,
#  'club': 11,
#  'total': 11,
#  'respect': 11,
#  'announc': 11,
#  'tf': 11,
#  'suppos': 11,
#  'round': 11,
#  'selfi': 11,
#  'stuck': 11,
#  'complet': 11,
#  'trip': 11,
#  'becom': 11,
#  'color': 11,
#  'detail': 11,
#  'sens': 11,
#  'manag': 11,
#  'pain': 11,
#  'design': 11,
#  'usual': 11,
#  'email': 11,
#  'engag': 11,
#  'card': 11,
#  'fair': 11,
#  'insid': 11,
#  'comment': 11,
#  'bullshit': 11,
#  'ugh': 11,
#  'death': 11,
#  'marri': 11,
#  'arriv': 11,
#  'huge': 11,
#  'remind': 11,
#  'child': 11,
#  'hotel': 11,
#  'bit': 11,
#  'updat': 11,
#  'share': 11,
#  'tax': 11,
#  'paper': 11,
#  'lay': 11,
#  'media': 11,
#  'glenn': 11,
#  'femal': 11,
#  'fit': 11,
#  'till': 11,
#  'worri': 11,
#  'speak': 11,
#  'jack': 11,
#  'haha': 11,
#  'quot': 11,
#  'along': 11,
#  'tea': 11,
#  'obsess': 11,
#  'transform': 11,
#  'min': 10,
#  'st': 10,
#  'action': 10,
#  'appli': 10,
#  'xx': 10,
#  'war': 10,
#  'american': 10,
#  'chocol': 10,
#  'kick': 10,
#  'easi': 10,
#  'af': 10,
#  'king': 10,
#  'fave': 10,
#  'draw': 10,
#  'review': 10,
#  'internet': 10,
#  'tweep': 10,
#  'tip': 10,
#  'rn': 10,
#  'due': 10,
#  'bottl': 10,
#  'histori': 10,
#  'summer': 10,
#  'low': 10,
#  'front': 10,
#  'public': 10,
#  'lyric': 10,
#  'anim': 10,
#  'moon': 10,
#  'gym': 10,
#  'gener': 10,
#  'special': 10,
#  'ignor': 10,
#  'reach': 10,
#  'emot': 10,
#  'gave': 10,
#  'repli': 10,
#  'cannot': 10,
#  'beat': 10,
#  'beach': 10,
#  'will': 10,
#  'spread': 10,
#  'nail': 10,
#  'serious': 10,
#  'hungri': 10,
#  'kinda': 10,
#  'son': 10,
#  'absolut': 10,
#  'complain': 10,
#  'fine': 10,
#  'excus': 10,
#  'exactli': 10,
#  'radio': 10,
#  'wash': 10,
#  'connect': 10,
#  'written': 10,
#  'nobodi': 10,
#  'horribl': 10,
#  'pass': 10,
#  'event': 10,
#  'goodby': 10,
#  'quit': 10,
#  'scari': 10,
#  'weather': 10,
#  'snap': 10,
#  're': 10,
#  'ad': 10,
#  'explain': 10,
#  'glad': 10,
#  'awkward': 10,
#  'hoe': 10,
#  'workbench': 10,
#  'storag': 10,
#  'colour': 9,
#  'daughter': 9,
#  'bond': 9,
#  'teach': 9,
#  'term': 9,
#  'four': 9,
#  'fast': 9,
#  'appreci': 9,
#  'holiday': 9,
#  'cant': 9,
#  'wednesday': 9,
#  'young': 9,
#  'anyway': 9,
#  'husband': 9,
#  'dr': 9,
#  'tie': 9,
#  'swear': 9,
#  'scream': 9,
#  'caught': 9,
#  'wall': 9,
#  'or': 9,
#  'sale': 9,
#  'yall': 9,
#  'charact': 9,
#  'attempt': 9,
#  'wifi': 9,
#  'cup': 9,
#  'sent': 9,
#  'bear': 9,
#  'matter': 9,
#  'extra': 9,
#  'join': 9,
#  'non': 9,
#  'about': 9,
#  'three': 9,
#  'ga': 9,
#  'giveaway': 9,
#  'afternoon': 9,
#  'been': 9,
#  'receiv': 9,
#  'mail': 9,
#  'situat': 9,
#  'pack': 9,
#  'messag': 9,
#  'becaus': 9,
#  'sun': 9,
#  'wors': 9,
#  'rip': 9,
#  'taken': 9,
#  'save': 9,
#  'biggest': 9,
#  'wa': 9,
#  'band': 9,
#  'credit': 9,
#  'includ': 9,
#  'id': 9,
#  'bore': 9,
#  'bunch': 9,
#  'forgot': 9,
#  'imagin': 9,
#  'shower': 9,
#  'potter': 9,
#  'control': 9,
#  'mr': 9,
#  'dumb': 9,
#  'rick': 9,
#  'rais': 9,
#  'edit': 9,
#  'xxx': 8,
#  'etc': 8,
#  'autumn': 8,
#  'sat': 8,
#  'america': 8,
#  'seri': 8,
#  'scene': 8,
#  'report': 8,
#  'greatest': 8,
#  'bought': 8,
#  'cooki': 8,
#  'memori': 8,
#  'congrat': 8,
#  'iron': 8,
#  'continu': 8,
#  'featur': 8,
#  'funniest': 8,
#  'success': 8,
#  'diamond': 8,
#  'surviv': 8,
#  'soooo': 8,
#  'click': 8,
#  'key': 8,
#  'mess': 8,
#  'fill': 8,
#  'mental': 8,
#  'amount': 8,
#  'board': 8,
#  'journal': 8,
#  'research': 8,
#  'activ': 8,
#  'tear': 8,
#  'asleep': 8,
#  'crack': 8,
#  'notic': 8,
#  'soon': 8,
#  'joke': 8,
#  'model': 8,
#  'either': 8,
#  'market': 8,
#  'view': 8,
#  'count': 8,
#  'accept': 8,
#  'partner': 8,
#  'schedul': 8,
#  'fix': 8,
#  'sell': 8,
#  'team': 8,
#  'brush': 8,
#  'la': 8,
#  'librari': 8,
#  'bride': 8,
#  'monster': 8,
#  'smoke': 8,
#  'decis': 8,
#  'none': 8,
#  'blood': 8,
#  'articl': 8,
#  'respond': 8,
#  'professor': 8,
#  'touch': 8,
#  'entir': 8,
#  'paid': 8,
#  'realiti': 8,
#  'daili': 8,
#  'cancel': 8,
#  'hill': 8,
#  'fab': 8,
#  'deep': 8,
#  'makeup': 8,
#  'piss': 8,
#  'cold': 8,
#  'queen': 8,
#  'pop': 8,
#  'taylor': 8,
#  'current': 8,
#  'felt': 8,
#  'struggl': 8,
#  'mc': 8,
#  'snapchat': 8,
#  'mcm': 8,
#  'butt': 8,
#  'surpris': 8,
#  'trash': 8,
#  'polic': 8,
#  'info': 8,
#  'brown': 8,
#  'hospit': 8,
#  'emoji': 8,
#  'bar': 8,
#  'ruin': 8,
#  'talent': 8,
#  'bath': 8,
#  'convers': 8,
#  'advic': 8,
#  'sexi': 8,
#  'sweet': 8,
#  'ice': 8,
#  'process': 8,
#  'twd': 8,
#  'paint': 8,
#  'netflix': 8,
#  'clear': 8,
#  'organ': 8,
#  'gorgeou': 7,
#  'wit': 7,
#  'after': 7,
#  'doubl': 7,
#  'appoint': 7,
#  'wine': 7,
#  'nah': 7,
#  'yep': 7,
#  'version': 7,
#  'kept': 7,
#  'exclus': 7,
#  'earth': 7,
#  'mac': 7,
#  'emili': 7,
#  'exhaust': 7,
#  'auction': 7,
#  'most': 7,
#  'grey': 7,
#  'grate': 7,
#  'compani': 7,
#  'hr': 7,
#  'brought': 7,
#  'tori': 7,
#  'bs': 7,
#  'note': 7,
#  'bird': 7,
#  'hilari': 7,
#  'winter': 7,
#  'um': 7,
#  'bf': 7,
#  'plu': 7,
#  'area': 7,
#  'our': 7,
#  'dick': 7,
#  'titl': 7,
#  'natur': 7,
#  'major': 7,
#  'store': 7,
#  'twin': 7,
#  'bank': 7,
#  'blow': 7,
#  'besid': 7,
#  'appl': 7,
#  'shot': 7,
#  'church': 7,
#  'attent': 7,
#  ...}

# %% [markdown]
# #### So,From the above calculation,
# ###### The Most Common WORD  used by Females is "I" which was used 2311 times !
# ###### The most Common EMOTION used by Females is "love" which was used 275 times !!

# %% [markdown]
# ## 2. Which Gender has more number of tweet count ? On an average what is the tweet_count by each gender ?

# %%
# Reading the data
information = pd.read_excel('information.xlsx')

# %%
# Selecting the required features
information = information[["gender", "tweet_count"]]

# %%
information.gender.value_counts()
# Out:
# female     6700
# male       6194
# brand      5942
# unknown    1117
# Name: gender, dtype: int64

# %%
information.shape
# Out:
# (20050, 2)

# %%
# Going through each row and summing up the number of tweets for each gender and storing in a Dictionary

tweet_counter= {}
for i in range(information.shape[0]):
    for gen in ["male", "female","brand","unknown"]: 
        if information.gender[i] == gen :
            if not gen in tweet_counter:
                tweet_counter[gen] = information.tweet_count[i]
            else:
                tweet_counter[gen] += information.tweet_count[i]

# %%
# Sorting the Dictionary with the Values in Descending Order
{k: v for k, v in sorted(tweet_counter.items(), key=lambda item: item[1], reverse =True )}
# Out:
# {'brand': 357391498,
#  'male': 196947006,
#  'female': 182821554,
#  'unknown': 39498482}

# %% [markdown]
# ###### So, From above it is clear that Gender "brand" has more number of tweet count

# %%
# Counting the users with respect to gender

gender_counter = information.gender.value_counts().to_dict()
gender_counter
# Out:
# {'female': 6700, 'male': 6194, 'brand': 5942, 'unknown': 1117}

# %%
# Finding the average number of tweets per gender

avg_tweet ={}
for i in ["male", "female","brand","unknown"]: 
    avg_tweet[i] = tweet_counter[i]/gender_counter[i]

# %%
avg_tweet
# Out:
# {'male': 31796.416855020987,
#  'female': 27286.799104477614,
#  'brand': 60146.66745203635,
#  'unknown': 35361.21933751119}

# %% [markdown]
# ##### The above dictionary shows the average number of Tweets per Gender

# %% [markdown]
# ## 3.Which user_timezone has the maximum number of tweet_count ?

# %%
# Reading the dataset
information = pd.read_excel('information.xlsx')

# %%
information.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
# Feature Selection
information = information[["tweet_count","user_timezone"]]

# %%
information.head()
# Out:
#    tweet_count               user_timezone
# 0       110964                     Chennai
# 1         7471  Eastern Time (US & Canada)
# 2         5617                    Belgrade
# 3         1693  Pacific Time (US & Canada)
# 4        31462                         NaN

# %%
information.dropna()
# Out:
#        tweet_count                user_timezone
# 0           110964                      Chennai
# 1             7471   Eastern Time (US & Canada)
# 2             5617                     Belgrade
# 3             1693   Pacific Time (US & Canada)
# 5            20036   Central Time (US & Canada)
# ...            ...                          ...
# 20035         7004       Atlantic Time (Canada)
# 20037         9092   Eastern Time (US & Canada)
# 20040         3084   Central Time (US & Canada)
# 20041       105864  Mountain Time (US & Canada)
# 20042         5900   Eastern Time (US & Canada)
#
# [12252 rows x 2 columns]

# %%
# Grouping the rows with user_name and summing the tweet_count per each group
time_zone_df = information.groupby("user_timezone").apply(lambda df : df.tweet_count.sum() )

# Converting the dataframe into dictionary
time_zone= time_zone_df.to_dict()

# %%
# Sorting the Dictionary with the Values in Descending Order

{k: v for k, v in sorted(time_zone.items(), key=lambda item: item[1], reverse =True )}
# Out:
# {'Eastern Time (US & Canada)': 98357334,
#  'Pacific Time (US & Canada)': 71544592,
#  'Central Time (US & Canada)': 61922748,
#  'Greenland': 60723348,
#  'London': 52189674,
#  'Quito': 17947020,
#  'Atlantic Time (Canada)': 15896405,
#  'Athens': 13234586,
#  'Amsterdam': 12806919,
#  'Mountain Time (US & Canada)': 11124841,
#  'Dublin': 9879517,
#  'Arizona': 9094219,
#  'Jakarta': 8108113,
#  'Paris': 7401029,
#  'Brasilia': 7163338,
#  'Casablanca': 6847366,
#  'Bangkok': 6786071,
#  'Hawaii': 6126527,
#  'Alaska': 4613600,
#  'Berlin': 4268337,
#  'West Central Africa': 3717841,
#  'Chennai': 3184703,
#  'Jerusalem': 3007450,
#  'Bucharest': 2644839,
#  'Singapore': 2593536,
#  'Santiago': 2308833,
#  'Caracas': 2022244,
#  'Baghdad': 1980295,
#  'New Delhi': 1864468,
#  'Pretoria': 1835789,
#  'Riyadh': 1779279,
#  'Brussels': 1727932,
#  'Melbourne': 1676363,
#  'Buenos Aires': 1638962,
#  'Abu Dhabi': 1586130,
#  'Beijing': 1460602,
#  'Mid-Atlantic': 1372970,
#  'Nairobi': 1363063,
#  'Sydney': 1347732,
#  'Seoul': 1345937,
#  'Mumbai': 1345405,
#  'Rome': 1337879,
#  'Madrid': 1315975,
#  'Belgrade': 1304818,
#  'Lisbon': 1178345,
#  'Bern': 1174836,
#  'Wellington': 1158937,
#  'Yakutsk': 1105263,
#  'Edinburgh': 1095831,
#  'Irkutsk': 1065577,
#  'Ljubljana': 1055853,
#  "Nuku'alofa": 1043511,
#  'Kuala Lumpur': 1008816,
#  'Hong Kong': 1003850,
#  'Karachi': 993080,
#  'Tashkent': 886873,
#  'Mexico City': 883668,
#  'Indiana (East)': 880962,
#  'Stockholm': 812015,
#  'Kyiv': 797186,
#  'Tokyo': 788027,
#  'Prague': 698276,
#  'Tijuana': 682265,
#  'Tallinn': 629113,
#  'Brisbane': 607423,
#  'Warsaw': 601458,
#  'Harare': 578385,
#  'Cairo': 575067,
#  'Yerevan': 529399,
#  'Auckland': 510787,
#  'Urumqi': 505978,
#  'Europe/Athens': 476734,
#  'Zagreb': 476291,
#  'Minsk': 469239,
#  'Tehran': 465478,
#  'Saskatchewan': 451579,
#  'Perth': 450680,
#  'Budapest': 408529,
#  'Samoa': 407092,
#  'Helsinki': 397667,
#  'America/New_York': 355890,
#  'La Paz': 351062,
#  'Kuwait': 343337,
#  'Europe/London': 317998,
#  'Copenhagen': 312050,
#  'Taipei': 294485,
#  'Chihuahua': 292574,
#  'Africa/Lagos': 287866,
#  'Newfoundland': 272590,
#  'International Date Line West': 271097,
#  'Bratislava': 264748,
#  'Vienna': 256970,
#  'Cape Verde Is.': 254898,
#  'Hanoi': 253487,
#  'Sri Jayawardenepura': 246806,
#  'Mazatlan': 233560,
#  'Central America': 209635,
#  'America/Toronto': 207956,
#  'New Caledonia': 206633,
#  'Skopje': 197475,
#  'America/Detroit': 197286,
#  'Magadan': 195945,
#  'Darwin': 192446,
#  'UTC': 184917,
#  'Monrovia': 180868,
#  'Kabul': 178365,
#  'Bogota': 176203,
#  'Islamabad': 157203,
#  'Moscow': 157051,
#  'Krasnoyarsk': 140713,
#  'Canberra': 134401,
#  'Georgetown': 130163,
#  'Adelaide': 118374,
#  'Azores': 102082,
#  'Ulaan Bataar': 95235,
#  'Asia/Karachi': 91419,
#  'Solomon Is.': 91362,
#  'Istanbul': 90626,
#  'Sofia': 89339,
#  'Fiji': 87428,
#  'Monterrey': 86695,
#  'Lima': 85389,
#  'Kolkata': 80679,
#  'Muscat': 77358,
#  'Volgograd': 72314,
#  'America/Los_Angeles': 65895,
#  'Dhaka': 60354,
#  'America/Vancouver': 53841,
#  'Australia/Brisbane': 53613,
#  'BST': 44342,
#  'Midway Island': 36803,
#  'America/Chicago': 29416,
#  'Europe/Sarajevo': 27023,
#  'Riga': 20719,
#  'Vilnius': 20108,
#  'Europe/Paris': 19267,
#  'Baku': 16187,
#  'CST': 13677,
#  'Guam': 13673,
#  'Guadalajara': 12806,
#  'Almaty': 10023,
#  'Osaka': 8355,
#  'Hobart': 7831,
#  'Novosibirsk': 7102,
#  'PDT': 3591,
#  'Africa/Cairo': 3242,
#  'CDT': 2828,
#  'GMT+3': 1644,
#  'EDT': 975,
#  'PST': 801,
#  'America/Boise': 760,
#  'Europe/Moscow': 475,
#  'IST': 237,
#  'Ekaterinburg': 41,
#  'Africa/Nairobi': 22,
#  'America/Argentina/Buenos_Aires': 21}

# %% [markdown]
# ###### From above Dictionary It is clear that Eastern Time (US & Canada) has maximum number of Tweet Counts from users
